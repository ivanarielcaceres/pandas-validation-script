# %%
import pandas as pd

# %%
validations = {
    'MXZCVEOPE': {
          'data_type': str,
          'data_type_length': 2,
          'required': True,
          'blanks': None,
          'only_numbers': None,
          'only_chars': True,
          'alfa': None,
          'exact_length': None,
          'min_length': None,
          'max_length': None,
          'pattern': None
    },
    '/BIC/MXZCVEOPE': {
          'data_type': str,
          'data_type_length': 20,
          'required': None,
          'blanks': None,
          'only_numbers': None,
          'only_chars': None,
          'alfa': None,
          'exact_length': None,
          'min_length': None,
          'max_length': None,
          'pattern': None
    },
    '/BIC/HMPS_PSID': {
          'data_type': str,
          'data_type_length': 24,
          'required': None,
          'blanks': None,
          'only_numbers': None,
          'only_chars': None,
          'alfa': None,
          'exact_length': None,
          'min_length': None,
          'max_length': None,
          'pattern': None
    },
    'CALDAY': {
          'data_type': str,
          'data_type_length': 24,
          'required': None,
          'blanks': None,
          'only_numbers': None,
          'only_chars': None,
          'alfa': None,
          'exact_length': None,
          'min_length': None,
          'max_length': None,
          'pattern': 'YYYY.MM.DD'
    },
    '/BIC/HMMATPAD': {
          'data_type': str,
          'data_type_length': 24,
          'required': True,
          'blanks': None,
          'only_numbers': True,
          'only_chars': None,
          'alfa': None,
          'exact_length': None,
          'min_length': None,
          'max_length': None,
          'pattern': None
    },
    '/BIC/HMVPTYP': {
          'data_type': str,
          'data_type_length': 24,
          'required': None,
          'blanks': None,
          'only_numbers': None,
          'only_chars': None,
          'alfa': None,
          'exact_length': None,
          'min_length': None,
          'max_length': None,
          'pattern': None
    },
    '/BIC/ZRPREVENT': {
          'data_type': str,
          'data_type_length': 24,
          'required': None,
          'blanks': None,
          'only_numbers': None,
          'only_chars': None,
          'alfa': None,
          'exact_length': None,
          'min_length': None,
          'max_length': None,
          'pattern': None
    },
    'ZMXKVGR4': {
          'data_type': str,
          'data_type_length': 24,
          'required': None,
          'blanks': None,
          'only_numbers': None,
          'only_chars': None,
          'alfa': None,
          'exact_length': None,
          'min_length': None,
          'max_length': None,
          'pattern': None
    },
    'ZC_KOF': {
          'data_type': int,
          'data_type_length': 24,
          'required': None,
          'blanks': None,
          'only_numbers': None,
          'only_chars': None,
          'alfa': None,
          'exact_length': None,
          'min_length': None,
          'max_length': None,
          'pattern': None
    },
    'ZBZIRK': {
          'data_type': str,
          'data_type_length': 24,
          'required': None,
          'blanks': None,
          'only_numbers': None,
          'only_chars': None,
          'alfa': None,
          'exact_length': None,
          'min_length': None,
          'max_length': None,
          'pattern': None
    },
    'ZZONA': {
          'data_type': str,
          'data_type_length': 24,
          'required': None,
          'blanks': None,
          'only_numbers': None,
          'only_chars': None,
          'alfa': None,
          'exact_length': None,
          'min_length': None,
          'max_length': None,
          'pattern': None
    },
    'MXESTADOG': {
          'data_type': int,
          'data_type_length': 24,
          'required': None,
          'blanks': None,
          'only_numbers': None,
          'only_chars': None,
          'alfa': None,
          'exact_length': None,
          'min_length': None,
          'max_length': None,
          'pattern': None
    },
    'ZAREA': {
          'data_type': str,
          'data_type_length': 24,
          'required': None,
          'blanks': None,
          'only_numbers': None,
          'only_chars': None,
          'alfa': None,
          'exact_length': None,
          'min_length': None,
          'max_length': None,
          'pattern': None
    },
    '/BIC/VTACFKPD': {
          'data_type': float,
          'data_type_length': 24,
          'required': None,
          'blanks': None,
          'only_numbers': None,
          'only_chars': None,
          'alfa': None,
          'exact_length': None,
          'min_length': None,
          'max_length': None,
          'pattern': 'M/MXKT/YY/XXXX/XXX'
    },
    '/BIC/VTACUKPD': {
          'data_type': float,
          'data_type_length': 24,
          'required': None,
          'blanks': None,
          'only_numbers': None,
          'only_chars': None,
          'alfa': None,
          'exact_length': None,
          'min_length': None,
          'max_length': None,
          'pattern': None
    },
    '/BIC/INGBP1KPD': {
          'data_type': float,
          'data_type_length': 24,
          'required': None,
          'blanks': None,
          'only_numbers': None,
          'only_chars': None,
          'alfa': None,
          'exact_length': None,
          'min_length': None,
          'max_length': None,
          'pattern': None
    },
    '/BIC/INSAP1KPD': {
          'data_type': float,
          'data_type_length': 24,
          'required': None,
          'blanks': None,
          'only_numbers': None,
          'only_chars': None,
          'alfa': None,
          'exact_length': None,
          'min_length': None,
          'max_length': None,
          'pattern': None
    }
}

# %%
validation_df = pd.DataFrame.from_dict(validations)
validation_df
# Out:
#                       MXZCVEOPE /BIC/MXZCVEOPE /BIC/HMPS_PSID         CALDAY  \
# alfa                       None           None           None           None
# blanks                     None           None           None           None
# data_type         <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# data_type_length              2             20             24             24
# exact_length               None           None           None           None
# max_length                 None           None           None           None
# min_length                 None           None           None           None
# only_chars                 True           None           None           None
# only_numbers               None           None           None           None
# pattern                    None           None           None     YYYY.MM.DD
# required                   True           None           None           None
#
#                   /BIC/HMMATPAD   /BIC/HMVPTYP /BIC/ZRPREVENT       ZMXKVGR4  \
# alfa                       None           None           None           None
# blanks                     None           None           None           None
# data_type         <class 'str'>  <class 'str'>  <class 'str'>  <class 'str'>
# data_type_length             24             24             24             24
# exact_length               None           None           None           None
# max_length                 None           None           None           None
# min_length                 None           None           None           None
# only_chars                 None           None           None           None
# only_numbers               True           None           None           None
# pattern                    None           None           None           None
# required                   True           None           None           None
#
#                          ZC_KOF         ZBZIRK          ZZONA      MXESTADOG  \
# alfa                       None           None           None           None
# blanks                     None           None           None           None
# data_type         <class 'int'>  <class 'str'>  <class 'str'>  <class 'int'>
# data_type_length             24             24             24             24
# exact_length               None           None           None           None
# max_length                 None           None           None           None
# min_length                 None           None           None           None
# only_chars                 None           None           None           None
# only_numbers               None           None           None           None
# pattern                    None           None           None           None
# required                   None           None           None           None
#
#                           ZAREA       /BIC/VTACFKPD    /BIC/VTACUKPD  \
# alfa                       None                None             None
# blanks                     None                None             None
# data_type         <class 'str'>     <class 'float'>  <class 'float'>
# data_type_length             24                  24               24
# exact_length               None                None             None
# max_length                 None                None             None
# min_length                 None                None             None
# only_chars                 None                None             None
# only_numbers               None                None             None
# pattern                    None  M/MXKT/YY/XXXX/XXX             None
# required                   None                None             None
#
#                    /BIC/INGBP1KPD   /BIC/INSAP1KPD
# alfa                         None             None
# blanks                       None             None
# data_type         <class 'float'>  <class 'float'>
# data_type_length               24               24
# exact_length                 None             None
# max_length                   None             None
# min_length                   None             None
# only_chars                   None             None
# only_numbers                 None             None
# pattern                      None             None
# required                     None             None

# %%
import numpy as np

df = pd.read_csv('files/17_10_SALES_OTH_MX.CSV',sep='|', converters={'/BIC/HMMATPAD': lambda x: str(x)})
df.replace(r'\s+', np.nan, regex=True, inplace=True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:2785: DtypeWarning: Columns (8) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %% [markdown]
# results = [['Your file has errors'], ['Your file contains 3 Names errors', 'Column 1, Row 3', 'Column 2, Row 5', 'Column 2, Row 6'],
# ['Your file does not have Type errors'], ['Your file does not have Length errors'], ['Your file contains 2 Pattern errors','Columnn 2, Row 1', 'Column 2, Row 4'

# %%
results = [[], [], [], [], []]

# %%
import math
import re

def validate_row(row):
    global results
    for index, val in row.iteritems():
        print('Column: {}'.format(row.name))
        print('Value: {}'.format(str(val)))
        print('Data type: {}'.format(type(val)))
        print('Row: {}'.format(index))
        print(val is None)
        
        # If the filed is empty (NaN or None) and the field validation is not required, continue for the next loop
        if ((type(val) is float and math.isnan(val)) or (val is None)) \
            and (validation_df.loc['required'][row.name] is not True):
            print('The field is empty and the filed validation is not required, ...')
            continue
            
        # If the filed is empty (NaN or None) and the field validation is required, insert column and row and continue for the next loop
        if ((type(val) is float and math.isnan(val)) or (val is None)) \
            and (validation_df.loc['required'][row.name] is True):
            print('The field is empty and the filed validation is required, ...')
            results[2].append('Column: {}, Row: {}'.format(row.name, index))
            continue
                 
        #CHECK FOR LENGTH ERRORS
        #required, blanks, data_type_lenght, exact_length, max_lenght, min_length
        if (type(val) is str and (validation_df.loc['data_type_length'][row.name] and len(val) > validation_df.loc['data_type_length'][row.name]) \
             or (validation_df.loc['min_length'][row.name] and len(val) < validation_df.loc['min_length'][row.name]) \
             or (validation_df.loc['max_length'][row.name] and len(val) > validation_df.loc['max_length'][row.name]) \
             or (validation_df.loc['exact_length'][row.name] and len(val) != validation_df.loc['exact_length'][row.name])):
                
            print('ERROR validation length')
            results[2].append('Column: {}, Row: {}'.format(row.name, index))
        
        # CHECK FOR DATATYPE ERRORS
        # datatype
        if validation_df.loc['data_type'][row.name] and type(val) is not validation_df.loc['data_type'][row.name]:     
            print('ERROR validation datatype')
            results[3].append('Column: {}, Row: {}'.format(row.name, index))
            
        # only_number 
        if validation_df.loc['only_numbers'][row.name] and validation_df.loc['only_numbers'][row.name] is True and not str(val).isdigit():     
            print('ERROR validation datatype, only number')
            results[3].append('Column: {}, Row: {}'.format(row.name, index))
            
        #only_char
        if validation_df.loc['only_chars'][row.name] and validation_df.loc['only_chars'][row.name] is True and not bool(re.match('^[a-zA-Z]+$', str(val))):     
            print('ERROR validation datatype, only char')
            results[3].append('Column: {}, Row: {}'.format(row.name, index))
            
        # CHECK FOR PATTERN ERRORS
        # datatype
        if validation_df.loc['pattern'][row.name]:     
            print('ERROR validation pattern')
            results[4].append('Column: {}, Row: {}'.format(row.name, index))

# %%
df.head(5).apply(lambda x: validate_row(x))

# %%
if len(results[2]) > 0:
    results[2].insert(0, 'Your file contains: {} Length errors'.format(len(results[2])))
else:
    results[2].insert(0, 'Your file does not have Length errors')
    
if len(results[3]) > 0:
    results[3].insert(0, 'Your file contains: {} Datatype errors'.format(len(results[3])))
else:
    results[3].insert(0, 'Your file does not have Data type errors')

# If n_check, l_check, t_check or p_check is greater than 1, then the files has errors 
if len(results[1]) > 1 or len(results[2]) > 1 or len(results[3]) > 1 or len(results[4]) > 1:
    results[0].insert(0, 'Your file has errors')
else:
    results[0].insert(0, 'Your file does not have errors')    
print(results)

# %%
#date_fmt = '2018.12.23'
